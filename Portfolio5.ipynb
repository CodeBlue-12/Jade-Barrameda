# %% [markdown]
# Jade B. Barrameda BSChE-1B
# # PORTFOLIO 5: STRINGS

# %%
print ('Hello World!') #Just a thing to begin with

# %% [markdown]
# PROGRAM PROPER

# %%
# To show current date and time
import datetime 
now = datetime.datetime.now()
date = now.strftime("%B %d, %Y")

#To insert delays in-between the prompts
import time

#User Interface
print('Booting...')
time.sleep(2)
print('Redirecting to Business Letter Coded Organizer in:')
for x in [3, 2, 1]:
    print(x)
    time.sleep(1.3)

#Details of the Sender
print('Welcome, user! To continue, please state your name (L.N., F.N. M.I.):')
whole_name = input()
name1_parts = whole_name.split()
no = len(name1_parts[0]) 
xx = name1_parts[0]
lastname1 = xx[:no - 1]

print('Hello,', name1_parts[1], '! Would you like to start?')
input()
print('Insert your address:')
y_address = input()
print('Contact Number:')
y_contact = input()
print('E-mail Address:')
y_email = input()
print('Position in the company')
y_pos = input()

#Details of the Recipient
print('Input to whom do you want to send this letter (L.N., F.N. M.I.):')
recipient_name = input()
name2_parts = recipient_name.split()
print('Input titles / honorifics (Mr., Ms., Mx., etc):')
x_title = input()
print('Address:')
x_address = input()
print('Contact Number:')
x_contact = input()
print('E-mail Address:')
x_email = input()
print('Position in the company')
x_pos = input()

#Letter Contents
subject = input('Subject of the Letter: ')
RE = input('Reference Line (Enter nothing if not applicable): ') 
content1 = input('Introductory Paragraph: ')
content2 = input('The Body: ')
content3 = input('Closing Paragraph: ')

#Salutations and Ending
print('Choose salutations:')
print('1 - Dear...')
print('2 - To esteemed...')
print('3 - Hello...')
print('4 - To...')
salutation = input()
if salutation == '2':
    sal = 'To esteemed'
elif salutation == '3':
    sal = 'Hello'
elif salutation == '4':
    sal = 'To'
else:
    sal = 'Dear'

print('Choose valediction / closing:')
print('1 - Respectfully yours,')
print('2 - Truly yours,')
print('3 - Respectfully,')
print('4 - Best regards')
print('5 - Sincerely,')
valediction = input()
if valediction == '1':
    val = 'Respectfully yours,'
elif valediction == '2':
    val = 'Truly yours,'
elif valediction == '3':
    val = 'Respectfully,'
elif valediction == '4':
    val = 'Best regards,'
else:
    val = 'Sincerely,'

#Carbon Copy
ccs = ''
while True: 
    print('List of Carbon copy recipients:')
    nim = input()
    ccs += nim + ", "
    a = input('Add more recipients (Press "N" to stop): ')
    if a.upper() == 'N':
        break  

#Output (Business Letter)
print('Warning: The format used is standard; it might be different from format your institution accommodates.')
print('Recheck and revise if needed, especially the indentation and space')
print('Organizing data input...')
time.sleep(5)

print(RE)
print()
print(whole_name)
print(y_pos)
print(y_address)
print(y_email)
print(y_contact)
print(date)
print()
print(recipient_name)
print(x_pos)
print(x_address)
print(x_email)
print(x_contact)
print()
print('Subject:', subject)
print()
print(sal + ' ' + x_title + ' ' + name2_parts[0])
print()
print(content1)
print()
print(content2)
print()
print(content3)
print()
print(val)
print(name1_parts[1] + ' ' + name1_parts[0])
print()
print('CC:', ' ' * 3, ccs)
