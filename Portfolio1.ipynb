# %% [markdown]
# ### Jade B. Barrameda BSChE-1B

# %% [markdown]
# # PORTFOLIO 1: EXPRESSIONS

# %%
print ('Hello World!') #Just a thing to begin with

# %% [markdown]
# Program Proper

# %%
# User Details
y = input ("What is your name:",) #For identification
print ("Welcome" , y)
birthyear= input('Enter Birthyear:') #Age Verification
age = 2026 - int(birthyear)
print('Your age is',age)
(username)=input ('What will be your username?') #Nickname or username that the user wants to use, just for fun
print('Welcome',username,', I hope you enjoy')

#Preliminaries
print ('Welcome to the Personality Type Evaluator! This questionnaire will determine whether you are a introvert, ambivert, or an extrovert person.') #Explaining what is the questionnare about 
print ('This questionnaire consists of 10 question or statements, each you will have to rate 1 (strongly disagree) to 5 (strongly agree). Enjoy!!!') #Explaining how to answer the questions
input ('To start, type anything:') #Just something to pause the prompt
print ('Let us start!!!')

#Start of Questionnaire
#I used " instead of ' since it was used is some questions
q1 = int(input("1. I feel energized after spending time with a large group: "))
q2 = int(input("2. I prefer speaking over writing: "))
q3 = int(input("3. I am comfortable being the center of attention: "))
q4 = int(input("4. I tend to 'think out loud' rather than internally: "))
q5 = int(input("5. I find small talk easy and enjoyable: "))
q6 = int(input("6. I seek out new social environments frequently: "))
q7 = int(input("7. I feel lonely when I am alone for too long: "))
q8 = int(input("8. I am usually the first to start a conversation: "))
q9 = int(input("9. I process my emotions by talking to others: "))
q10 = int(input("10. I would describe myself as an 'open book': "))

# Processing of Data
value = (q1 + q2 + q3 + q4 + q5 + q6 + q7 + q8 + q9 + q10)/10 #Getting the average of the answers that will serve as basis for the identification
input('Do you want to see the results? Type anything to continue:') #Just something to pause the prompt
print ('Your score is...' , value , '!!!')
print ('To know your personality type, compare your score to the following thresholds below:') 
#Since conditional was the next topic, I can't use the concept; therefore, I resorted to this.
print ('1.0 - 2.5: Introvert')
print ('2.6 - 3.5: Ambivert')
print ('3.6 - 5.0: Extrovert')

#Feedback
input ('On the scale of 1 (useless) to 5 (helpful), how would you rate this activity?')
print ('Thank you very much', username ,'!')
